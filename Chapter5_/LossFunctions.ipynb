# %%
figsize( 9, 3.5)

# %% [markdown]
# # Chapter 4:
# ## Would you rather lose an arm or a leg?
# ____

# %% [markdown]
# Statisticians can be a sour bunch. Instead of considering thier winnings, the only worry about how much they are losing. In fact, they consider their wins to be negative loses!
#
# The author Nassim Taleb of *The Black Swan* and *Antifragility* stresses the importance of *payoffs* of decisions, *not the accuracy*. For example, consider the following vignette:
#
# >   A meteorologist is predicting the probability of a possible hurricane striking his region. He estimates, with 95% confidence (whatever this means), that the probability of it *not* striking is between 99% - 100%. He is very happy with his precision and advises the city that major evacuation is unecessary. Unfortunately, the hurricane does strike and the city is flooded.
#
# The stylized example shows the flaw in using a pure accuracy metrix to measre how good your estimate is, while an appealing and *objective* thing to do, misses the point: decision making.

# %% [markdown]
# ### Loss Functions
#
# We introduce what statisticians and decisions theorist call *loss functions*. A loss function is a function of the true parameter, and an estimate of that parameter
#
# $$ L( \theta, \hat{\theta} ) = f( \theta, \hat{\theta} )$$
#
# The important point of loss functions is that it measures how *bad* our current estimate is: the large the loss, the worse the estimate. For example, the *squared-error loss* is a very common loss function, defined:
#
# $$ L( \theta, \hat{\theta} ) = ( \theta -  \hat{\theta} )^2$$
#
# The squared-error loss function is used in estimators like linear regression and many areas of machine learning \cite. We can also consider an asymmetric loss function, something like:
#
# $$ L( \theta, \hat{\theta} ) = \begin{cases} ( \theta -  \hat{\theta} )^2 & \hat{\theta} \le \theta \\\\ c( \theta -  \hat{\theta} )^2 & \hat{\theta} \gt \theta, \;\; 0\lt c \lt 1 \end{cases}$$
#
#
# which means estimating smaller than the true estimate is better than above. A situation where this might be useful is in estimating next month's sales, where a more pessemistic outlook is preferred to avoid overallocation of resources. A negative thing about the squared-error loss is that is puts more emphasis on large outliers as the loss increases quadraticly. The more *robust* loss function that increases linearly with the difference is the *absolute-loss*
#
# $$ L( \theta, \hat{\theta} ) = | \theta -  \hat{\theta} | $$
#
# Other popular loss function include:
#
# -  $ L( \theta, \hat{\theta} ) = \mathbb{1}_{ \hat{\theta} \neq \theta } $ is the zero-one loss often used in machine learning classification algorithms.
# -  $ L( \theta, \hat{\theta} ) = -\hat{\theta}\log( \theta ) - (1-\hat{ \theta})\log( 1 - \theta ), \; \; \hat{\theta} \in {0,1}, \; \theta \in [0,1]$$, called the *log-loss*, also used in machine learning.
#
# Histroically, loss functions have been motivated from 1) mathematical convience, and 2) they are robust to application, i.e., the are objective measures of loss. The first reason has really held back the full breath of loss functions in application. With computers being agnogstic to mathematical convience, we are free to design our own loss functions.
#
# The above loss functions are indeed objective, in that they are most often a function of the difference between estimate and true parameter, independent of signage or payoff of choosing that estimate. This last point, its independence of payoff, causes quite pathological results. Consider our hurricane example above: the statistician equivilantly predicted that the probability of the hurricane striking was 0% to 1%. But if he had ignored being precise and instead focused on outcomes, he might have advised differently.
#
# By shifting our focus from trying to be incredibly precise about parameters to focusing on the outcomes of our inference, we can customize our estimates to be optimized for our application. This requires us to create new loss functions that reflect our goals and outcomes.
#
#
# - $ L( \theta, \hat{\theta} ) = \frac{ | \theta - \hat{\theta} | }{ \theta(1-\theta) }, \; \; \hat{\theta}, \theta \in [0,1] $ emphasizes an estimate closer to 0 or 1 since if the true value $\theta$ is near 0 or 1, the loss will be *very* large unless $\hat{\theta}$ is equally as close 0 or 1.
# This loss function might be used by a political pundit who's job requires him or her to give confidence "Yes/No" answers. This loss reflects that if the true parameter is close to 1 (for example, if a political outcome is very biased toward 1), he or she would want to strongly agree as to not look like a fool.
#
# -  $L( \theta, \hat{\theta} ) =  1 - \exp \left( (\theta -  \hat{\theta} )^2 \right) $ is bounded between 0 and 1 and reflect that the user is indifferent to suffiently missed estimates. It is similar to the zero-one loss above, but not quite as penalizing to estimates that are nearby.
# -  Complicated non-linear loss functions can programmed:
#
#         def loss(true_value, estimate):
#             if estimate*true_value > 0:
#                 return abs( estimate - true_value)
#             else:
#                return abs(estimate)*(estimate - true_value)**2
#
#
#
# -  Another example from the book *The Signal and The Noise* is that weather forcasters have a loss function.
#
#
# >  *People notice one type of mistake--the failure to predict rain--more than other, false alarms. If it rains when it isn't supposed to, they curse the weatherman for ruining their picnic, whereass an unexpectedly sunny day is taken as a serendipitous bonus.*
#
# >  *[The Weather Channel's bias] is limited to slightly exaggerating the probability of rain when it is unlikely to occur--saying there is a 20 percent change when they know it is really a 5 or 10 percent chance--covering their butts in the case of an unexpected sprinkle.*
#
#
# As you can see, loss functions can be used for good and evil: with great power, comes great-- well you know.

# %% [markdown]
# ##  Loss functions in the real world
#
# So far we have been under the unrealistic assumption that we know the true parameter, then even bothering to create an estimate is a redundant task. Hence a loss function is only practial if it is wrapped by an expected value, where the true parameter is random variable. Random variable? Parameter? Bayesian.
#
# First it will be useful to explain a *Bayesian point esimate*. Our world and machinery in our world are not built to accept a posterior distribution as input. We need to distill our posterior distribution down to a single number (or vector in the multivariate case). If done correctly, we can avoid the flaw of frequentist methodologies that mask the uncertainity and provide a more informative number.
#
# As Bayesian analysis returns a posterior distribution of the parameters, we can examine the expected value of loss function of the (random) parameters. For example, suppose $P(\theta | X)$ is the posterior distribution of $\theta$ after observing data $X$, then the following function is understandable:
#
# $$ l(\hat{\theta} ) = E_{\theta}\left[ \; L(\theta, \hat{\theta}) \; \right] $$
#
# which measures the *expected loss* of using estimate $\hat{\theta}$, also known as the *risk* of estimate $\hat{\theta}$. The subscript $\theta$ under the expectation symbol is to denote that $\theta$ is the random variable in the expectation, something that at first can be challening to think about.
#
# We spent all of last chapter discussing how to approximate expected values. Given $N$ samples $\theta_i,\; i=1,...,N$ from the posterior distribution, and a loss $L$, we can approximate the expected loss of using estimate $\hat{\theta}$ by the Law of Large Numbers:
#
# $$\frac{1}{N} \sum_{i=1}^N \;L(\theta_i, \hat{\theta} ) \approx E_{\theta}\left[ \; L(\theta, \hat{\theta}) \; \right]  = l(\hat{\theta} ) $$
#
# Notice that measuring your loss via an *expected value* uses more information from the distribution than the MAP estimate which, if you recall, will only find the maximum value and ignore the shape of the distribution. Ignoring this information can overexpose yourself to tail risks and leaves yourself ignorant to how ignorant you really are about the parameter (which is important!).
#
# Similarly, compare this with frequentist methods, that traditionally only aim to be minimize the error, and not the more-broad loss of that assuming that error. Compounded this with the fact that frequentist methods are almost garunteed to have an error. Loss functions fix this by planning ahead: your estimate is going to be wrong, you might as well err on the right side of wrong.

# %% [markdown]
# ______________________________________
# ### Example: Optimizing the *Showdown Showcase* on *The Price is Right*
#
# Bless you if you are ever choosen as a contestant on the Price is Right, for here we will show you how to optimize your final price on the *Showcase Showdown*. For those who forget the rules:
#
# 1. Two contestants compete in the *Showcase Showdown*.
# 2. Each contestant is shown a unique suite of prizes (we'll assume two, but our analysis can be extended to any number).
# 3. After the viewing, the contestants are asked to bid on the price for their unique suite of prizes.
# 4. If a bid price is **over** the actual price, the bid's owber is disqualified from winning (unless both bids are over, then the closest bid's owner wins), else the winner is the closer of the two bets to the true prices.
#
# What might a contestants loss function look like? I would think it would look something like:
#
#     def showdown_loss( guess, true_price, pain = 80000):
#         if true_price < guess:
#             return pain
#         else:
#             return np.abs( true_price - guess )
#
# where `pain` is a level of how bad it is if your guess is over the true price. A lower `pain` means that you are more comfortable with the idea of going over (remember going over does not gauruntee you lose--your competitor might go over as well). If we do bid under, we want to be as close as possible, hence the `else` loss is a increasing function of the distance between the guess and true price.
#
# Suppose we have recorded the *Showcase Showdowns* from previous *The Price is Right* episodes and have *prior* beliefs about what distribution the true price follows. For simplicty, suppose it follows a Normal:
#
# $$\text{True Price} \sim \text{Normal}(\mu_p, \sigma_p )$$
#
# We need a model of how we should think playingv the *Showdown*. For each prize, we have an idea of what it might cost, but this could be significantly off of the true price. (Couple this with increased pressure being onstage and you can see why some bids are so wildly off). Let's be rational and suppose your beliefs about both (remember we assumed two prizes, but this can be extended) prices of prizes also follow Normal distributions:
#
# $$ \text{Prize}_i \sim \text{Normal}(\mu_i, \sigma_i ),\;\; i=1,2$$
#
# This is really why Bayesian analysis is great: we can specify what we think a fair price is through the $\mu_i$ parameter, and express uncertainty of our guess in the $\sigma_i$ parameter. The true price of the prize suite is given by $\text{Prize}_1 + \text{Prize}_2 $.
#
#
# We are interested in the updated $\text{True Price}$ given we have observed both prizes and have belief distributions about them. We can perform this is PyMC. Below, I assumed the following parameters for our prior beliefs:
#
# \begin{align*}
# & \text{Prize}_1 \sim \text{Normal}(15000, 5000 )\\\\
# & \text{Prize}_2 \sim \text{Normal}(20000, 5000 )\\\\
# &\text{True Price} \sim \text{Normal}(50000, 10000 )
# \end{align*}

# %%
import pymc as mc

data_mu = [ 1.5e4, 2.0e4]

data_std =  [ 5e3, 5e3 ] 

mu_prior = 5e4
std_prior =  1e4 

true_price = mc.Normal( "true_price", mu_prior, 1.0/std_prior**2 )


prize_1 = mc.Normal( "first_prize", data_mu[0], 1.0/data_std[0]**2 )
prize_2 = mc.Normal( "second_prize", data_mu[1], 1.0/data_std[1]**2 )
price_estimate = prize_1 + prize_2

@mc.potential
def error( true_price = true_price, price_estimate = price_estimate ):
        return mc.normal_like( true_price,  price_estimate, 1e-8)


model = mc.Model([true_price, prize_1, prize_2, price_estimate, error ])
mcmc = mc.MCMC(model)
mcmc.sample( 200000, 180000) 

price_trace = mcmc.trace( "true_price"  )[:]
# Out:
# [****************100%******************]  200000 of 200000 complete

# %%
_hist = plt.hist( price_trace, bins = 50, normed= True, histtype= "stepfilled")
plt.title( "Posterior of the true price estimate" )
plt.vlines( mu_prior, 0, 1.1*np.max(_hist[0] ), label = "prior's mean" )
plt.vlines( price_trace.mean(), 0, 1.1*np.max(_hist[0] ), \
    label = "posterior's mean", linestyles  = "--")
plt.legend()

# %% [markdown]
# Notice that because of our two observational prizes, we shifted our previous price estimate down about $6000 dollars.
#
# A frequentist, seeing the two prizes and having the same beliefs about there prices, would bid $\mu_1 + \mu_2 = 35000$, regardless of any uncertainty. Meanwhile, the *naive Bayesian* would simply pick the mean of the posterior distribution. But we have more information about our eventual outcomes, so we should incorporate this into our bid. We will use the loss function above to find the **best** bid (*best* according to our loss).
#
# For every bid, we calculate the *expected loss* associated with that bid. We vary the pain parameter to see how it affects our loss:

# %%
figsize( 8.5, 7 )
#numpy friendly showdown_loss
def showdown_loss( guess, true_price, pain = 80000):
        loss = np.zeros_like( true_price )
        ix = true_price < guess
        loss[ix] = pain
        loss[~ix] = np.abs( guess - true_price[~ix] )
        return loss


guesses = np.linspace( 5000, 50000, 25) 
pains = np.linspace( 30000, 150000, 6 )
expected_loss = lambda guess, pain: \
            showdown_loss( guess, price_trace, pain ).mean()
        
for _p in pains:
    results = [ expected_loss( _g, _p ) for _g in guesses ]
    plt.plot( guesses, results, label = "pain: %d"%_p )
    
plt.title("Expected loss of different guesses, \nvarious pain-levels of \
overestimating")
plt.legend( loc="upper left")
plt.xlabel("price bid")
plt.ylabel("expected loss")
plt.xlim( 15000, 50000 )
# Out:
# (15000, 50000)

# %% [markdown]
# _______
#
# ### Minimizing our losses
#
# We would like to minimize our expected loss by finding the solution to
#
# $$ \text{arg} \min_{\hat{\theta}} \;\;E_{\theta}\left[ \; L(\theta, \hat{\theta}) \; \right] $$
#
# The minimum of the expected loss is called the *Bayes action*. We can solve for the Bayes action using Scipy's optimization routines. The function in `fmin` in `scipy.optimize` module uses an intelligent search to find a minimum (not necessarily a *global* minimum) of any uni- or multivariate function. For most purposes, `fmin` will provide you with a good answer.
#
# We'll compute the minimum loss for the *Showcase Showdown* example above:

# %%
import scipy.optimize as sop

ax = subplot(111)


for _p in pains:
    _color = ax._get_lines.color_cycle.next()
    _min_results = sop.fmin( expected_loss, 30000, args=(_p,), disp = False)
    _results = [ expected_loss( _g, _p ) for _g in guesses ]
    plt.plot( guesses, _results , color = _color )
    plt.scatter( _min_results, 0, s = 60, color= _color,\
         label = "minimum expected loss at pain %d"%_p)
    
    print "minimum at pain %d: %.2f"%( _p, _min_results )
                                    
plt.title("Expected loss of different guess, \nvarious pain-levels of \
overestimating")
plt.legend( loc="upper left", scatterpoints = 1)
plt.xlabel("price guess")
plt.ylabel("expected loss")
plt.xlim( 15000, 50000 )
plt.ylim( -1000, 120000)
# Out:
# minimum at pain 30000: 35968.58
# minimum at pain 54000: 32960.13
# minimum at pain 78000: 31574.91
# minimum at pain 102000: 30398.19
# minimum at pain 126000: 30398.19
# minimum at pain 150000: 28049.37
# (-1000, 120000)

# %% [markdown]
# As intution suggests, as we decrease the pain theshold, we increase our bid, willing to edge closer to the true price.
#
# Suffice to say, in higher dimensions being able to eyeball the minimum expected loss is impossible. Hence why we require use of Scipy's `fmin` function.
#
#
# ### Can we do better?
#
# Let's try to pick a rational `pain` value. I would assume that bidding over the true price should be equivilant to guessing \$1: essentially you are handing the keys to winning to your opponent. Hence we should modify our loss to reflect this.  Hypothetically, if you bid \$1, we'll measure your loss as `true_price**2`. So your rational pain should be equal to this.  To encourage an even closer estimate, we will use some square-error losses in this new loss function.

# %%
def showdown_lossII( guess, true_price):
        loss = np.zeros_like( true_price )
        ix = true_price < guess
        loss[ix] = true_price**2
        loss[~ix] = np.abs( guess - true_price[~ix] )**2 #notice we squared here.
        return loss

guesses = np.linspace( 5000, 50000, 25) 

expected_lossII = lambda guess: \
            showdown_lossII( guess, price_trace ).mean()
        

results = [expected_lossII( _g ) for _g in guesses ]
plt.plot( guesses, results )
    
_min_results = sop.fmin( expected_lossII, 30000 )
plt.scatter( _min_results, expected_lossII(_min_results), s = 60,\
         color="k") 
print "Bayes action at %.2f"%_min_results
plt.title("Expected loss of guess; more rational loss")
plt.xlabel("price guess")
plt.ylabel("expected loss")
# Out:
# Optimization terminated successfully.
#          Current function value: 320182879.617768
#          Iterations: 56
#          Function evaluations: 116
# Bayes action at 31579.83

# %% [markdown]
# #### Shortcuts
#
# For some loss functions, the Bayes action is known in closed form. We list some of them below:
#
# -  If using the mean-squared loss, the Bayes action is the mean the positerior distribution, i.e. the value
# $$ E_{\theta}\left[ \theta \right] $$
#
# >  minimizes $E_{\theta}\left[ \; (\theta - \hat{\theta})^2 \; \right]$. Computationally this requires us the caluculate the average of the posterior samples [See chapter 4 on The Law of Large Numbers]
#
# -  Whereas the *median* of the posterior distribution minimizes the expected absolute-loss. The sample median of the posterior samples is an appropriate and very acccurate approximiation to the true median.
#
# -  Infact, it is possible to show that the MAP estimate is the solution to using a loss function that shrinks to the zero-one loss.
#
#
# Maybe it is clear now why the first-introduced loss functions are used most often in the mathematics of Bayesian inference: no complicated optimizations are necessary. Luckily, we have machines to do the complications for us.
#
# ### Machine Learning via Bayesian Methods
#
# Whereas frequentist methods strive to achieve the best precision amount all possible parameters, machine learning cares to acheive the best *prediction* among all possible parameters. Of course, one way to achieve accurate predictions is to aim for accurate predictions, but often your prediction measure and what frequentist methods are optimizing for are very different.
#
# For example, least-squares linear regression is the most simple active machine learning algorithm. I say active as it engages in some learning, whereas predicting the sample mean is technically *simplier*, but is learning very little. The loss that determines the coefficients of the variables is a squared-error loss. On the other hand, if your prediction loss function (or score function, which is the negative loss) is not a squared-error, like AUC, ROC, precision, etc., your least-squares line will not be optimal for the prediction loss function. This can lead to results that are  suboptimal.
#
# Finding Bayes actions is equilivant to finding parameters that optimizes *not parameter accuracy* but an arbitrary performance measure, however we wish to define loss (AUC, ROC, precision etc.).
#
#
# ### Prediction
#
# Until now, we have only been concerned with fitting the observed data. Of course, going further and being able to predict unforseen data is much more valuable (and difficult). As alluded to in Chapter 2, prediction in a Bayesian context is equivilant to finding the posterior of some unknown parameter (the predictable variable).

# %% [markdown]
# ____
# ### Example: Financial losses
#
# Using a square-error loss function to estimate the price of a stock tomorrow is a poor decision. This is because the square-error loss function is agnostic to the sign of the predicted and true parameter, whereas in reality, the signage is very important. Consider: predicting the price movement's sign correctly but being slightly off the price movement's magnitude is much more preferable to the opposite situation. Let's define the following loss:

# %%
figsize(9, 3.5)
def stock_loss( true_return, yhat, alpha = 100. ):
    if true_return*yhat < 0:
        #opposite signs, not good
        return alpha*yhat**2 - sign( true_return )*yhat + abs( true_return ) 
    else:
        return abs( true_return - yhat )
    
    
true_value = .05
pred = np.linspace( -.04, .12, 50 )

plt.plot( pred, [stock_loss( true_value, _p) for _p in pred], label = "Loss \
associated with\n prediction if true value = 0.05") 
plt.vlines( 0, 0, .25, linestyles="--" )
plt.legend()
plt.xlabel( "prediction")
plt.ylabel( "loss" )
plt.xlim( -0.04, .12 )
plt.title("Stock returns (subjective) loss if true value = 0.05" )

# %% [markdown]
# Note the change in the shape of the loss as the prediction cross 0. This loss reflects that the user really does not want to guess the wrong sign, especially be wrong *and* a large magnitude.
#
# We will perform a regression on some signal that we think predicts returns. Our dataset is artificial, as most financial data is not even close to linear. We plot the data below along with the least-squares line.

# %%
## Code to create artificial data
N = 100
X = 0.025*np.random.randn(N )
Y = 0.5*X + 0.04*np.random.randn( N) 

beta = np.cov( X, Y )[0,1]/np.var(X)
alpha = Y.mean() - beta*X.mean()

plt.scatter( X, Y)
plt.xlabel("trading signal")
plt.ylabel("returns")
plt.title( "Empirical returns vs trading signal" )
plt.plot( X, beta*X + alpha)
plt.xlim( X.min(), X.max())
plt.ylim( Y.min(), Y.max() )
# Out:
# (-0.13503046419037434, 0.10506573523445903)

# %% [markdown]
# let's perform a Bayesian linear regression on this dataset. We look for a model like:
#
# $$ \text{return}_i = \alpha + \beta \text{signal}_i + \epsilon$$
#
# where $\alpha, \beta$ are our unknown parameters and $\epsilon \sim \text{Normal}(0, 1/\tau)$. The most common priors on $\beta$ and $\alpha$ are Normal priors. We will also assign a prior on $\tau$, so that $1/\sqrt{\tau}$ is uniform over 0 to 100.

# %%
import pymc as mc
from pymc.Matplot import plot as mcplot

std = mc.Uniform( "std", 0, 100, trace = False ) #this needs to be explained.

@mc.deterministic
def prec( U = std ):
    return 1.0/np.sqrt( U )

beta = mc.Normal( "beta", 0, 0.0001 )
alpha = mc.Normal( "alpha", 0, 0.0001 )

@mc.deterministic
def mean( X = X, alpha = alpha, beta = beta ):
    return alpha + beta*X
    
obs = mc.Normal( "obs", mean, prec, value = Y, observed = True)
model = mc.Model( {"obs":obs, "beta_0":beta, "alpha_0":alpha, "prec":prec} )
mcmc = mc.MCMC( model )

mcmc.sample( 200000, 180000)
mcplot( mcmc )
# Out:
# [****************100%******************]  200000 of 200000 complete
# Plotting beta
# Plotting
#  alpha
# Plotting
#  prec

# %%
new_trading_signal =  np.linspace( X.min(), X.max() )
for _signal in new_trading_signal:
